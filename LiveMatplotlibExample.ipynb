# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import style
import numpy as np
import time
# %matplotlib notebook

# %%
'''This is a lineplot (?) example'''
data = np.random.rand(100)
timeStamps = np.arange(0.0, 100, 1)

fig, ax = plt.subplots()
ax.plot(timeStamps, data)

ax.set(xlabel='time (s)', ylabel='acceleration',
       title='A read from the accelerometer vs time')
ax.grid()

# fig.savefig("test.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#This is a live example I stole from stack overflow
# plt.axis([0, 10, 0, 1])

# for i in range(10):
#     y = np.random.random()
#     plt.scatter(i, y)
#     plt.pause(0.5)

#     plt.show()


fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

def animate(i):
#     pullData = open("sampleText.txt","r").read()
#     dataArray = pullData.split('\n')
    data = np.random.rand(100)
    timeStamps = np.arange(0.0, 100, 1)
#     for eachLine in dataArray:
#         if len(eachLine)>1:
#             x,y = eachLine.split(',')
#             xar.append(int(x))
#             yar.append(int(y))
    ax1.clear()
    ax1.plot(timeStamp,data)
ani = animation.FuncAnimation(fig, animate, interval=1000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def pltsin(ax, colors=['b']):
    x = np.linspace(0,1,100)
    if ax.lines:
        for line in ax.lines:
            line.set_xdata(x)
            y = np.random.random(size=(100,1))
            line.set_ydata(y)
    else:
        for color in colors:
            y = np.random.random(size=(100,1))
            ax.plot(x, y, color)
    fig.canvas.draw()
    
    
fig,ax = plt.subplots(1,1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_xlim(0,1)
ax.set_ylim(0,1)
for f in range(5):
    pltsin(ax, ['b', 'r'])
    time.sleep(1)
# Out:
# <img src="data:image/png;base64,..." width="640">
